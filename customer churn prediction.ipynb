# %%
import pandas as pd

# %%
data=pd.read_csv('Churn_Modelling[1].csv')

# %%
 data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
data.shape
# Out:
# (10000, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
data.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
data.describe(include='all')
# Out:
#           RowNumber    CustomerId Surname   CreditScore Geography Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000     10000  10000
# unique          NaN           NaN    2932           NaN         3      2
# top             NaN           NaN   Smith           NaN    France   Male
# freq            NaN           NaN      32           NaN      5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800       NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299       NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000       NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000       NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000       NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000       NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000       NaN    NaN
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# ...

# %%
data.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
data=data.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)

# %%
data.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
data['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
 data=pd.get_dummies(data, drop_first=True)

# %%
data.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1              False
# 1               1        112542.58       0              False
# 2               0        113931.57       1              False
# 3               0         93826.63       0              False
# 4               1         79084.10       0              False
#
#    Geography_Spain  Gender_Male
# 0            False        False
# 1             True        False
# 2            False        False
# 3            False        False
# 4             True        False

# %%
data['Exited'].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(data['Exited'])
# Out:
# <Axes: ylabel='count'>

# %%
x=data.drop('Exited', axis=1)
y=data['Exited']

# %%
 from imblearn.over_sampling import SMOTE

# %%
x_res, y_res=SMOTE().fit_resample(x,y)

# %%
y_res.value_counts()
# Out:
# Exited
# 1    7963
# 0    7963
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test=train_test_split(x_res,y_res, test_size=0.2, random_state=42, stratify=y_res)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.57335134,  0.60498926,  0.43438446, ..., -0.76728533,
#         -0.63123944,  0.81036844],
#        [ 0.30271468, -1.49187213, -1.41140903, ...,  1.30329613,
#         -0.63123944, -1.2340066 ],
#        [ 0.57648531, -1.99112484,  1.54186056, ..., -0.76728533,
#          1.58418492, -1.2340066 ],
#        ...,
#        [ 0.10559982, -0.99261942, -0.67309163, ...,  1.30329613,
#         -0.63123944, -1.2340066 ],
#        [-1.30705663, -0.39351616,  0.06522576, ..., -0.76728533,
#         -0.63123944, -1.2340066 ],
#        [ 0.02894405, -0.69306779, -0.30393293, ..., -0.76728533,
#         -0.63123944,  0.81036844]])

# %%
 from sklearn.linear_model import LogisticRegression

# %%
reg=LogisticRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred=reg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7696170747018205

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
 precision_score(y_test,y_pred)
# Out:
# 0.7740906190172304

# %%
recall_score(y_test, y_pred)
# Out:
# 0.7614563716258631

# %%
f1_score(y_test, y_pred)
# Out:
# 0.7677215189873418

# %%
from sklearn import svm

# %%
svm=svm.SVC()

# %%
svm.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred1=svm.predict(x_test)

# %%
accuracy_score(y_test, y_pred1)
# Out:
# 0.8333333333333334

# %%
precision_score(y_test, y_pred1)
# Out:
# 0.8425806451612903

# %%
recall_score(y_test, y_pred1)
# Out:
# 0.8198367859384809

# %%
f1_score(y_test, y_pred1)
# Out:
# 0.8310531339484569

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred2=knn.predict(x_test)

# %%
accuracy_score(y_test, y_pred2)
# Out:
# 0.8145009416195856

# %%
precision_score(y_test, y_pred2)
# Out:
# 0.8088779284833539

# %%
recall_score(y_test, y_pred2)
# Out:
# 0.8236032642812304

# %%
f1_score(y_test, y_pred2)
# Out:
# 0.8161741835147744

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred3=dt.predict(x_test)

# %%
accuracy_score(y_test, y_pred3)
# Out:
# 0.7984934086629002

# %%
precision_score(y_test, y_pred3)
# Out:
# 0.7873111782477341

# %%
recall_score(y_test, y_pred3)
# Out:
# 0.8179535467671061

# %%
f1_score(y_test, y_pred3)
# Out:
# 0.8023399014778325

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred4=rf.predict(x_test)

# %%
accuracy_score(y_test, y_pred4)
# Out:
# 0.8600125549278091

# %%
precision_score(y_test, y_pred4)
# Out:
# 0.8673926969891096

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb=GradientBoostingClassifier()

# %%
gb.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred5=gb.predict(x_test)

# %%
accuracy_score(y_test, y_pred5)
# Out:
# 0.8370998116760828

# %%
precision_score(y_test, y_pred5)
# Out:
# 0.8482490272373541

# %%
final_data=pd.DataFrame({'Models': ['LR', 'SVC', 'KNN', 'DT', 'RF', 'GBC'], 'ACC': [accuracy_score(y_test, y_pred),accuracy_score(y_test, y_pred1), accuracy_score(y_test, y_pred2), accuracy_score(y_test, y_pred3), accuracy_score(y_test, y_pred4), accuracy_score(y_test, y_pred5)]})

# %%
final_data
# Out:
#   Models       ACC
# 0     LR  0.769617
# 1    SVC  0.833333
# 2    KNN  0.814501
# 3     DT  0.798493
# 4     RF  0.860013
# 5    GBC  0.837100

# %%
import seaborn as sns

# %%
sns.barplot(x='Models', y='ACC', data=final_data)
# Out:
# <Axes: xlabel='Models', ylabel='ACC'>

# %%
final_data=pd.DataFrame({'Models': ['LR', 'SVC', 'KNN', 'DT', 'RF', 'GBC'], 'PRE': [precision_score(y_test, y_pred),precision_score(y_test, y_pred1), precision_score(y_test, y_pred2), precision_score(y_test, y_pred3), precision_score(y_test, y_pred4), precision_score(y_test, y_pred5)]})

# %%
final_data
# Out:
#   Models       PRE
# 0     LR  0.774091
# 1    SVC  0.842581
# 2    KNN  0.808878
# 3     DT  0.787311
# 4     RF  0.867393
# 5    GBC  0.848249

# %%
sns.barplot(x='Models', y='PRE', data=final_data)
# Out:
# <Axes: xlabel='Models', ylabel='PRE'>

# %%
x_res=sc.fit_transform(x_res)

# %%
rf.fit(x_res, y_res)
# Out:
# RandomForestClassifier()

# %%
import joblib

# %%
joblib.dump(rf, 'churn_predict_model')
# Out:
# ['churn_predict_model']

# %%
model=joblib.load('churn_predict_model')

# %%
data.columns
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'Geography_Germany',
#        'Geography_Spain', 'Gender_Male'],
#       dtype='object')

# %%
model.predict('61
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[270], line 1
# ----> 1 model.predict('612', '51', '3', '10000', '1', '1', '0', '100000', '0', '0', '0', '0')
#
# TypeError: ForestClassifier.predict() takes 2 positional arguments but 13 were given
